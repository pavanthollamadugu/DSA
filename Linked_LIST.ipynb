# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanthollamadugu/DSA/blob/main/Linked_LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Linked List

# %%
#A linked list is a type of linear data structure individual items are not necessarily at contiguous locations.
# The individual items are called nodes and connected with each other using links.

# %%
class Node:
    def __init__(self, data):
        self.data = data      # stores value
        self.next = None      # reference to next node

class LinkedList:
    def __init__(self):
        self.head = None      # head pointer

# %%
from IPython.display import HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
    <style>
        body { font-family: Arial; line-height: 1.6; padding: 20px; }
        h2 { color: #2c3e50; }
        .diagram {
            font-family: monospace;
            background: #f4f4f4;
            padding: 10px;
            border-left: 4px solid #3498db;
            margin: 10px 0;
        }
    </style>
</head>
<body>

<h1>Types of Linked List</h1>

<h2>1. Singly Linked List</h2>
<div class="diagram">
Head → [1 | 111] → [2 | 222] → [4 | 333] → [5 | NULL]
</div>

<p>
Each node contains:
<ul>
<li>Data</li>
<li>Reference to the next node</li>
</ul>
</p>

<h2>2. Circular Singly Linked List</h2>
<div class="diagram">
Head → [1 | 111] → [2 | 222] → [4 | 333] → [5 | 001]<br>
↑______________________________________________|
</div>

<p>
The last node stores a reference to the first node.
</p>

<h3>Example</h3>
<p>LUDO GAME</p>

</body>
</html>
"""

HTML(html_code)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         body { font-family: Arial; line-height: 1.6; padding: 20px; }
#         h2 { color: #2c3e50; }
#         .diagram {
#             font-family: monospace;
#             background: #f4f4f4;
#             padding: 10px;
#             border-left: 4px solid #3498db;
#             margin: 10px 0;
#         }
#     </style>
# </head>
# <body>
#
# <h1>Types of Linked List</h1>
#
# <h2>1. Singly Linked List</h2>
# <div class="diagram">
# Head → [1 | 111] → [2 | 222] → [4 | 333] → [5 | NULL]
# </div>
#
# <p>
# Each node contains:
# <ul>
# <li>Data</li>
# <li>Reference to the next node</li>
# </ul>
# </p>
#
# <h2>2. Circular Singly Linked List</h2>
# <div class="diagram">
# Head → [1 | 111] → [2 | 222] → [4 | 333] → [5 | 001]<br>
# ↑______________________________________________|
# </div>
#
# <p>
# The last node stores a reference to the first node.
# </p>
#
# <h3>Example</h3>
# <p>LUDO GAME</p>
#
# </body>
# </html>
